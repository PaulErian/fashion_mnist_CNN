# %% [markdown]
# **Auteur :** Paul Erian

# %% [markdown]
# # Préparation de la BDD

# %% [markdown]
# **Bibliothèques et Téléchargements**

# %%
# Import
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# Telechargement Fashion MNIST
train, test = tf.keras.datasets.fashion_mnist.load_data()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Récupération des données**

# %%
# Nom des classes
dict_labels = { 0: 'T-shirt/top',
              1: 'Trouser',
              2: 'Pullover',
              3: 'Dress',
              4: 'Coat',
              5: 'Sandal',
              6: 'Shirt',
              7: 'Sneaker',
              8: 'Bag',
              9: 'Ankle boot'}

# %%
train_imgs   = train[0]
train_labels = train[1]
N_training = train_imgs.shape[0]
print(f"Nb données entrainement + validation : {N_training}.")
# Out:
# Nb données entrainement + validation : 60000.

# %%
# Organisation de la BDD
x_train   = train_imgs[10000:]
y_train = train_labels[10000:]
x_val = train_imgs[:10000]
y_val = train_labels[:10000]
x_test    = test[0]
y_test  = test[1]

# %%
# Affichage de la taille
N_train = x_train.shape[0]
N_val = x_val.shape[0]
N_test  = x_test.shape[0]
print(f"Nb données entrainement : {N_train}.")
print(f"Nb données validation   : {N_val}.")
print(f"Nb données test         : {N_test}.")
# Out:
# Nb données entrainement : 50000.
# Nb données validation   : 10000.
# Nb données test         : 10000.

# %%
# Conversion
x_train = x_train.astype(np.float32)
y_train = y_train.astype(np.uint8)

x_val = x_val.astype(np.float32)
y_val = y_val.astype(np.uint8)

x_test = x_test.astype(np.float32)
y_test = y_test.astype(np.uint8)

# %% [markdown]
# **Visualisation des données**

# %%
# Visualisation
fig = plt.figure(figsize=(15,15))
for k in range(12):
  # chargement
  img = x_train[k,:,:]
  label_num = y_train[k]
  # affichage
  plt.subplot(3,4,k+1)
  plt.imshow(img,cmap='gray')
  plt.title(dict_labels[label_num])

fig.tight_layout()
plt.show()

# %% [markdown]
# **Création d'une BDD Tensorflow**

# %%
def one_hot_encoding(img, label):
  out = tf.one_hot(label,10,dtype=tf.uint8)
  return(img, out)

def add_channel(img, label):
  out = tf.expand_dims(img, axis=2)
  return(out, label)

def augment(img, label):
  out = tf.image.random_flip_left_right(img)
  return(out, label)


def normalise(img, label):
  mean = tf.reduce_mean(img)
  std = tf.math.reduce_std(img)
  out = (img - mean)/std
  return(out, label)

# %%
BATCH_SIZE = 32
def prepare_ds(x,y):
  ds = tf.data.Dataset.from_tensor_slices((x,y))
  ds = (ds
    .map(one_hot_encoding, num_parallel_calls=tf.data.AUTOTUNE)
    .map(add_channel, num_parallel_calls=tf.data.AUTOTUNE)
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .map(normalise, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
  )
  return ds

# %%
train_ds = prepare_ds(x_train, y_train)
val_ds = prepare_ds(x_val, y_val)
print(train_ds)
print(val_ds)
# Out:
# <PrefetchDataset shapes: ((None, 28, 28, 1), (None, 10)), types: (tf.float32, tf.uint8)>
# <PrefetchDataset shapes: ((None, 28, 28, 1), (None, 10)), types: (tf.float32, tf.uint8)>

# %% [markdown]
# **Construction du modèle**

# %%
# C32 -> ReLu -> Batchnorm -> Maxpool
# C64 -> ReLu -> Batchnorm -> Maxpool
# FC512 -> ReLu
# FC10 -> Softmax
def Model():
  inputs = tf.keras.Input(shape=(28, 28, 1), name='input_image')

  x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="SAME", activation="relu")(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='SAME')(x)

  x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), strides=1, padding="SAME", activation="relu")(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='SAME')(x)

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(512, activation='relu')(x)
  x = tf.keras.layers.Dropout(rate= 0.5)(x)
  outputs = tf.keras.layers.Dense(10, activation='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs)
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = Model()
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,630,474
# Trainable params: 1,630,282
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# # Entraînement

# %% [markdown]
# **Paramètres d'entrainement**

# %%
epochs = 30
learning_rate = 1e-3
loss = tf.keras.losses.CategoricalCrossentropy()
opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# %%
print(f"Nb epoch                : {epochs}")
print(f"Nb données entrainement : {N_train}")
print(f"Taille d'un lot         : {BATCH_SIZE}")
print(f"Nb étape par epoch      : { int(np.ceil(N_train/BATCH_SIZE)) }")
print(f"Fonctions de cout       : {loss.name}")
print(f"Optimisation            : Adam")
print(f"Learning rate           : {learning_rate}")
# Out:
# Nb epoch                : 30
# Nb données entrainement : 50000
# Taille d'un lot         : 32
# Nb étape par epoch      : 1563
# Fonctions de cout       : categorical_crossentropy
# Optimisation            : Adam
# Learning rate           : 0.001

# %% [markdown]
# **Métriques utilisées**

# %%
train_acc_metric = tf.keras.metrics.CategoricalAccuracy()
val_acc_metric = tf.keras.metrics.CategoricalAccuracy()

# %% [markdown]
# **Listes contenant les valeurs des métriques/ loss**

# %%
# pour 1 epoch
train_loss_list =[]
val_loss_list = []
# pour l'ensemble des epochs
train_loss_per_epoch = []
train_acc_per_epoch = []
val_loss_per_epoch = []
val_acc_per_epoch = []

# %% [markdown]
# **Test GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# **Chemin de sauvegarde dans le drive**

# %%
path = "/content/drive/MyDrive/saved_model"

# %% [markdown]
# **Entraînement**

# %%
train_from_scratch = True #@param {type:"boolean"}

if train_from_scratch:
  out_text = "entrainement à partir de 0"
  model = Model()
else:
  out_text = "entrainement à partir du dernier checkpoint"
  model = tf.keras.models.load_model(path)

print(out_text)
# Out:
# entrainement à partir de 0

# %%
for epoch in range(epochs):
  ## ENTRAINEMENT
  for step, (x_train_batch, y_train_batch) in enumerate(train_ds):
    # calcul de la loss
    with tf.GradientTape() as tape:
      logits = model(x_train_batch, training=True)
      loss_value = loss(y_train_batch, logits)
    # calcul du gradient
    grads = tape.gradient(loss_value, model.trainable_weights)
    # mise à jour des poids du réseau
    opt.apply_gradients(zip(grads, model.trainable_weights))
    # MAJ metrique
    train_loss_list.append(loss_value)
    train_acc_metric.update_state(y_train_batch, logits)

    # Affichage
    if step % 500 == 0:
      print("step : %d, loss : %.4f"% (step, float(loss_value)))
  
  ## VALIDATION
  for x_val_batch, y_val_batch in val_ds:
    val_logits = model(x_val_batch, training=False)
    val_loss_value = loss(y_val_batch, val_logits)
    # MAJ metrics
    val_loss_list.append(val_loss_value)
    val_acc_metric.update_state(y_val_batch, val_logits)

  ## CALCUL METRIQUE
  train_loss = np.sum(train_loss_list)/len(train_loss_list)
  train_acc = train_acc_metric.result()
  val_loss = np.sum(val_loss_list)/len(val_loss_list)
  val_acc = val_acc_metric.result()

  ## SAVE MODEL
  if (epoch ==0 or (smaller_val_loss>val_loss)):
    smaller_val_loss = val_loss
    model.save(path)

  ## AFFICHAGE
  print(f"Epoch {epoch+1}",end=" - ")
  print("Training loss: %.4f" % train_loss, end=" - ")
  print("Training accuracy: %.4f" % (float(train_acc)),end=" - ")
  print("Validation loss: %.4f" % val_loss, end=" - ")
  print("Validation accuracy: %.4f" % (float(val_acc)))

  ## SAUVEGARDE + RESET
  train_loss_per_epoch.append(train_loss)
  train_acc_per_epoch.append(train_acc)
  val_loss_per_epoch.append(val_loss)
  val_acc_per_epoch.append(val_acc)
  # reset metriques
  train_loss_list = []
  val_loss_list = []
  train_acc_metric.reset_states()
  val_acc_metric.reset_states()
# Out:
# step : 0, loss : 4.0571
# step : 500, loss : 0.5212
# step : 1000, loss : 1.1627
# step : 1500, loss : 0.6066
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 1 - Training loss: 0.5385 - Training accuracy: 0.8186 - Validation loss: 0.3295 - Validation accuracy: 0.8820
# step : 0, loss : 0.1848
# step : 500, loss : 0.3392
# step : 1000, loss : 0.7608
# step : 1500, loss : 0.3873
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 2 - Training loss: 0.3664 - Training accuracy: 0.8687 - Validation loss: 0.2843 - Validation accuracy: 0.8918
# step : 0, loss : 0.1204
# step : 500, loss : 0.2079
# step : 1000, loss : 0.9712
# step : 1500, loss : 0.4446
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 3 - Training loss: 0.3218 - Training accuracy: 0.8862 - Validation loss: 0.2811 - Validation accuracy: 0.8952
# step : 0, loss : 0.2881
# step : 500, loss : 0.2834
# step : 1000, loss : 0.6620
# step : 1500, loss : 0.5190
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 4 - Training loss: 0.2908 - Training accuracy: 0.8961 - Validation loss: 0.2396 - Validation accuracy: 0.9123
# step : 0, loss : 0.1379
# step : 500, loss : 0.1716
# step : 1000, loss : 0.8899
# step : 1500, loss : 0.3030
# Epoch 5 - Training loss: 0.2652 - Training accuracy: 0.9059 - Validation loss: 0.2518 - Validation accuracy: 0.9083
# step : 0, loss : 0.3857
# step : 500, loss : 0.1487
# step : 1000, loss : 0.7876
# step : 1500, loss : 0.3255
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 6 - Training loss: 0.2454 - Training accuracy: 0.9113 - Validation loss: 0.2256 - Validation accuracy: 0.9172
# step : 0, loss : 0.1529
# step : 500, loss : 0.1579
# step : 1000, loss : 0.8896
# step : 1500, loss : 0.3677
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 7 - Training loss: 0.2291 - Training accuracy: 0.9161 - Validation loss: 0.2239 - Validation accuracy: 0.9190
# step : 0, loss : 0.2000
# step : 500, loss : 0.2038
# step : 1000, loss : 0.8530
# step : 1500, loss : 0.1768
# Epoch 8 - Training loss: 0.2183 - Training accuracy: 0.9202 - Validation loss: 0.2361 - Validation accuracy: 0.9193
# step : 0, loss : 0.2371
# step : 500, loss : 0.0861
# step : 1000, loss : 0.8027
# step : 1500, loss : 0.1818
# Epoch 9 - Training loss: 0.2005 - Training accuracy: 0.9267 - Validation loss: 0.2330 - Validation accuracy: 0.9191
# step : 0, loss : 0.0800
# step : 500, loss : 0.2014
# step : 1000, loss : 0.5646
# step : 1500, loss : 0.3118
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_model/assets
# Epoch 10 - Training loss: 0.1864 - Training accuracy: 0.9320 - Validation loss: 0.2207 - Validation accuracy: 0.9205
# step : 0, loss : 0.1788
# step : 500, loss : 0.1271
# step : 1000, loss : 0.6886
# step : 1500, loss : 0.2105
# Epoch 11 - Training loss: 0.1773 - Training accuracy: 0.9349 - Validation loss: 0.2454 - Validation accuracy: 0.9114
# step : 0, loss : 0.1061
# step : 500, loss : 0.2353
# step : 1000, loss : 0.5252
# step : 1500, loss : 0.1498
# Epoch 12 - Training loss: 0.1712 - Training accuracy: 0.9372 - Validation loss: 0.2362 - Validation accuracy: 0.9189
# step : 0, loss : 0.1112
# step : 500, loss : 0.1061
# step : 1000, loss : 0.7497
# step : 1500, loss : 0.1928
# Epoch 13 - Training loss: 0.1600 - Training accuracy: 0.9419 - Validation loss: 0.2361 - Validation accuracy: 0.9223
# step : 0, loss : 0.1819
# step : 500, loss : 0.3482
# step : 1000, loss : 0.5391
# step : 1500, loss : 0.3387
# Epoch 14 - Training loss: 0.1534 - Training accuracy: 0.9442 - Validation loss: 0.2274 - Validation accuracy: 0.9222
# step : 0, loss : 0.0703
# step : 500, loss : 0.0654
# step : 1000, loss : 0.4534
# step : 1500, loss : 0.3042
# Epoch 15 - Training loss: 0.1451 - Training accuracy: 0.9474 - Validation loss: 0.2380 - Validation accuracy: 0.9201
# step : 0, loss : 0.0357
# step : 500, loss : 0.1534
# step : 1000, loss : 0.3795
# step : 1500, loss : 0.1182
# Epoch 16 - Training loss: 0.1382 - Training accuracy: 0.9490 - Validation loss: 0.2352 - Validation accuracy: 0.9245
# step : 0, loss : 0.0990
# step : 500, loss : 0.0507
# step : 1000, loss : 0.5188
# step : 1500, loss : 0.1247
# Epoch 17 - Training loss: 0.1328 - Training accuracy: 0.9517 - Validation loss: 0.2295 - Validation accuracy: 0.9255
# step : 0, loss : 0.0904
# step : 500, loss : 0.1060
# step : 1000, loss : 0.4212
# step : 1500, loss : 0.0427
# Epoch 18 - Training loss: 0.1247 - Training accuracy: 0.9549 - Validation loss: 0.2521 - Validation accuracy: 0.9252
# step : 0, loss : 0.0400
# step : 500, loss : 0.2200
# step : 1000, loss : 0.4243
# step : 1500, loss : 0.1591
# Epoch 19 - Training loss: 0.1195 - Training accuracy: 0.9562 - Validation loss: 0.2492 - Validation accuracy: 0.9279
# step : 0, loss : 0.0606
# step : 500, loss : 0.0472
# step : 1000, loss : 0.3193
# step : 1500, loss : 0.1821
# Epoch 20 - Training loss: 0.1144 - Training accuracy: 0.9582 - Validation loss: 0.2539 - Validation accuracy: 0.9269
# step : 0, loss : 0.0657
# step : 500, loss : 0.0648
# step : 1000, loss : 0.5037
# step : 1500, loss : 0.2674
# Epoch 21 - Training loss: 0.1108 - Training accuracy: 0.9595 - Validation loss: 0.2486 - Validation accuracy: 0.9284
# step : 0, loss : 0.0755
# step : 500, loss : 0.0616
# step : 1000, loss : 0.2562
# step : 1500, loss : 0.1149
# Epoch 22 - Training loss: 0.1107 - Training accuracy: 0.9601 - Validation loss: 0.2554 - Validation accuracy: 0.9313
# step : 0, loss : 0.0395
# step : 500, loss : 0.0696
# step : 1000, loss : 0.3708
# step : 1500, loss : 0.0765
# Epoch 23 - Training loss: 0.1045 - Training accuracy: 0.9620 - Validation loss: 0.2571 - Validation accuracy: 0.9285
# step : 0, loss : 0.1486
# step : 500, loss : 0.0265
# step : 1000, loss : 0.4920
# step : 1500, loss : 0.0981
# Epoch 24 - Training loss: 0.1055 - Training accuracy: 0.9620 - Validation loss: 0.2555 - Validation accuracy: 0.9289
# step : 0, loss : 0.0631
# step : 500, loss : 0.0221
# step : 1000, loss : 0.3701
# step : 1500, loss : 0.1289
# Epoch 25 - Training loss: 0.0985 - Training accuracy: 0.9647 - Validation loss: 0.2465 - Validation accuracy: 0.9293
# step : 0, loss : 0.0405
# step : 500, loss : 0.0315
# step : 1000, loss : 0.3687
# step : 1500, loss : 0.0962
# Epoch 26 - Training loss: 0.0915 - Training accuracy: 0.9664 - Validation loss: 0.3230 - Validation accuracy: 0.9197
# step : 0, loss : 0.0519
# step : 500, loss : 0.0564
# step : 1000, loss : 0.2491
# step : 1500, loss : 0.1527
# Epoch 27 - Training loss: 0.0897 - Training accuracy: 0.9673 - Validation loss: 0.2949 - Validation accuracy: 0.9265
# step : 0, loss : 0.0091
# step : 500, loss : 0.0527
# step : 1000, loss : 0.1841
# step : 1500, loss : 0.0269
# Epoch 28 - Training loss: 0.0868 - Training accuracy: 0.9679 - Validation loss: 0.2929 - Validation accuracy: 0.9247
# step : 0, loss : 0.0354
# step : 500, loss : 0.0474
# step : 1000, loss : 0.1864
# step : 1500, loss : 0.0487
# Epoch 29 - Training loss: 0.0830 - Training accuracy: 0.9688 - Validation loss: 0.2796 - Validation accuracy: 0.9314
# step : 0, loss : 0.0794
# step : 500, loss : 0.0497
# step : 1000, loss : 0.2273
# step : 1500, loss : 0.5302
# Epoch 30 - Training loss: 0.0820 - Training accuracy: 0.9690 - Validation loss: 0.3410 - Validation accuracy: 0.9268

# %% [markdown]
# **Résultats d'entrainement**

# %%
x = [(i+1) for i in range(epochs)]

plt.figure()
plt.plot(x,train_loss_per_epoch)
plt.plot(x,val_loss_per_epoch)
plt.xlabel("epoch number")
plt.ylabel("loss")
plt.legend(("train_loss","val_loss"))
plt.grid()
plt.title("traning and validation loss")

plt.figure()
plt.plot(x,train_acc_per_epoch)
plt.plot(x,val_acc_per_epoch)
plt.xlabel("epoch number")
plt.ylabel("accuracy")
plt.legend(("train_accuracy","val_accuracy"))
plt.grid()
plt.title("traning and validation accuracy")
# Out:
# Text(0.5, 1.0, 'traning and validation accuracy')

# %% [markdown]
# # Testing

# %% [markdown]
# **Métriques**

# %%
test_acc_metric = tf.keras.metrics.CategoricalAccuracy()
test_pres_metric = tf.keras.metrics.Precision()

# %% [markdown]
# **Test**

# %%
gt_list = []
pred_list = []
for k,(img, label_num) in enumerate(zip(x_test, y_test)):
  img, label_num = normalise(img,label_num)
  img, vec_label = one_hot_encoding(img, label_num)
  # chargement
  pred_vec = make_prediction(model,img)[0]
  # ajout aux listes de gt/prediction
  gt_list.append(label_num)
  pred_list.append(np.argmax(pred_vec))
  # calcul metriques
  test_acc_metric.update_state(vec_label,pred_vec)
  test_pres_metric.update_state(vec_label,pred_vec)
  if (k%500 == 0):
    print(f"{k}/{N_test}")
# Out:
# 0/10000
# 500/10000
# 1000/10000
# 1500/10000
# 2000/10000
# 2500/10000
# 3000/10000
# 3500/10000
# 4000/10000
# 4500/10000
# 5000/10000
# 5500/10000
# 6000/10000
# 6500/10000
# 7000/10000
# 7500/10000
# 8000/10000
# 8500/10000
# 9000/10000
# 9500/10000

# %% [markdown]
# **Accuracy et Precision**

# %%
print(f"Accuracy : {test_acc_metric.result().numpy()}")
print(f"Precision : {test_pres_metric.result().numpy()}")
# Out:
# Accuracy : 0.916100025177002
# Precision : 0.927361786365509

# %%
conf_mat = tf.math.confusion_matrix(gt_list, pred_list)
print("Matrice de confusion : ")
print(conf_mat.numpy())
print(dict_labels)
# Out:
# Matrice de confusion :
# [[879   0  10  14   7   1  86   0   3   0]
#  [  0 982   2   8   2   0   4   0   2   0]
#  [ 19   0 790   8  68   0 114   0   1   0]
#  [ 14   1   7 918  27   0  33   0   0   0]
#  [  0   0  15  22 900   0  63   0   0   0]
#  [  0   0   0   0   0 972   1  18   0   9]
#  [110   1  24  17  54   0 790   0   4   0]
#  [  0   0   0   0   0   2   0 980   0  18]
#  [  1   1   1   1   4   1   5   1 985   0]
#  [  0   0   0   0   0   4   1  30   0 965]]
# {0: 'T-shirt/top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 4: 'Coat', 5: 'Sandal', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boot'}
